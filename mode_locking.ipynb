# %%
from pulse_animation import *
# %config InlineBackend.figure_format = 'retina'

# %%
animate_resonator(np.linspace(0, 10, 100), np.linspace(0, 20, 400), n_modes=20, ms_between_frames=60)
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 4371.10it/s]
# <video width="792" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from pulse_animation import *
# %config InlineBackend.figure_format = 'retina'

# %%
d = resonator_modes(0.21, np.linspace(0, 1, 2000), 20, spectrum_std=1000)
b = resonator_modes(0.21, np.linspace(0, 1, 2000), 20, spectrum_std=1000, random_phases=True)
