# %%
import numpy as np
from cavity import animate_resonator

# %config InlineBackend.figure_format = 'retina'

# %%
animate_resonator(
    np.linspace(0, 10, 100), np.linspace(0, 20, 400), n_modes=40, ms_between_frames=60
)
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 2458.11it/s]
# 100%|██████████| 400/400 [00:00<00:00, 87774.49it/s]
# <video width="792" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import numpy as np
from cavity import resonator_modes

# %config InlineBackend.figure_format = 'retina'

# %%
d = resonator_modes(
    0.21,
    np.linspace(0, 1, 2000),
    30,
    spectrum_std=1000,
    save_in="plots/mode_locking/locked_phase",
)
b = resonator_modes(
    0.21,
    np.linspace(0, 1, 2000),
    30,
    spectrum_std=1000,
    save_in="plots/mode_locking/random_phase",
    random_phases=True,
)

# %%
b = resonator_modes(
    1,
    np.linspace(0, 1, 2000),
    3,
    spectrum_std=1000,
    save_in="plots/mode_locking/resonator_3modes/illustration",
    random_phases=True,
)
